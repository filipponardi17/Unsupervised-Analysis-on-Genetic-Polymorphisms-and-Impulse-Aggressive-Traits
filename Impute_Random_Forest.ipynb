# %%
# !pip install numpy --upgrade --ignore-installed
# !pip install scikit-learn
# !pip install shap
# Out:
# Collecting numpy
#   Using cached numpy-1.26.2-cp39-cp39-macosx_10_9_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.2-cp39-cp39-macosx_10_9_x86_64.whl (20.6 MB)
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.5.0 requires daal==2021.4.0, which is not installed.
# scipy 1.7.3 requires numpy<1.23.0,>=1.16.5, but you have numpy 1.26.2 which is incompatible.
# torchvision 0.15.1 requires torch==2.0.0, but you have torch 1.10.2 which is incompatible.
# Successfully installed numpy-1.22.4
#
# [notice] A new release of pip is available: 22.3.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: scikit-learn in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.22.4)
# Requirement already satisfied: scipy>=1.5.0 in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.7.3)
# Requirement already satisfied: joblib>=1.1.1 in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (2.2.0)
#
# [notice] A new release of pip is available: 22.3.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: shap in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (0.43.0)
# Requirement already satisfied: numpy in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from shap) (1.22.4)
# Requirement already satisfied: scipy in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from shap) (1.7.3)
# Requirement already satisfied: scikit-learn in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from shap) (1.3.2)
# Requirement already satisfied: pandas in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from shap) (1.5.3)
# Requirement already satisfied: tqdm>=4.27.0 in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from shap) (4.65.0)
# Requirement already satisfied: packaging>20.9 in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from shap) (23.1)
# Requirement already satisfied: slicer==0.0.7 in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from shap) (0.0.7)
# Requirement already satisfied: numba in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from shap) (0.58.1)
# Requirement already satisfied: cloudpickle in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from shap) (2.2.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from numba->shap) (0.41.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from pandas->shap) (2023.3.post1)
# Requirement already satisfied: joblib>=1.1.1 in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->shap) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->shap) (2.2.0)
# Requirement already satisfied: six>=1.5 in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
#
# [notice] A new release of pip is available: 22.3.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from  sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
#import shap
import numpy as np

# %%
# Data Processing
import pandas as pd
import numpy as np

# Modelling
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint

# Tree Visualisation
from sklearn.tree import export_graphviz
from IPython.display import Image
#import graphviz

# %%
data = pd.read_csv('Datasets/Eureca_Adapted.csv', header=0)
#print(data)
df = data
# Out:
# Columns (4,5,28,29,30,31,38,39,40,59) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
df.replace(' ', np.nan, inplace=True)

# Deleting records where any specified columns have empty strings ('')
names_list = [
    "BDNF_valmet",
    "COMT",
    "HT1A",
    "HT1B_161",
    "HT1B_861",
    "VHT2A_1438",
    "VHT2A_C102T",
    "VHTTP_mutation_seule",
    "VHTTP_LPR",
    "@_httpb_promoteur",
    "VHTTP_snippassocie",
    "VHTTP_Intron2",
    "TPH1_intron1b",
    "TPH1_promo",
    "TPH1_Intron3",
    "TPH1_Intron4",
    "TPH1_Intron7",
    "TPH1_Intron9",
    "TPH1_T8687",
    "TPH2_8997",
    "TPH2_9000_Eco72_1",
    "TPH2_9000_Aci_I",
    "TPH2_Intron5",
    "TPH2_Exon7",
    "TPH2_Intron9",
    "MAOA_Promo",
    "MAOA_promo_activite"
]

# Count NaN values for each row in the specified columns
nan_counts = df[names_list].isnull().sum(axis=1)

# Filter rows with more than 6 NaN values
rows_to_drop = nan_counts[nan_counts > 8].index #70% of 26 genes is 18.2

# Store the number of records to be dropped
num_records_dropped = len(rows_to_drop)

# Drop rows from the DataFrame
df.drop(rows_to_drop, inplace=True)

# Print the number of records dropped
print(f"{num_records_dropped} records were dropped.")
# Out:
# 6579 records were dropped.

# %%
len(df)
# Out:
# 2116

# %%
for column in df.columns:
    null_count = df[column].isnull().sum()
    print(f"Column '{column}' has {null_count} null value(s).")
# Out:
# Column 'IDENTIFICADOR' has 0 null value(s).
# Column 'source' has 0 null value(s).
# Column 'type' has 0 null value(s).
# Column 'assessment_date' has 509 null value(s).
# Column 'gender' has 0 null value(s).
# Column 'age' has 4 null value(s).
# Column 'ethnicity' has 5 null value(s).
# Column 'EST_CIV' has 936 null value(s).
# Column 'children' has 1157 null value(s).
# Column 'tabacco_act' has 871 null value(s).
# Column 'niv_edu' has 1034 null value(s).
# Column 'sit_lab' has 999 null value(s).
# Column 'his_fam_suicide_behavior' has 920 null value(s).
# Column 'his_fam_suicide' has 958 null value(s).
# Column 'his_fam_suicide_attempt' has 1068 null value(s).
# Column 'Suicidal_behavior' has 285 null value(s).
# Column 'num_suic_attempts' has 321 null value(s).
# Column 'age_first_attempt' has 818 null value(s).
# Column 'day_int' has 1359 null value(s).
# Column 'month_int' has 1288 null value(s).
# Column 'year_int' has 1202 null value(s).
# Column 'violent_suicide_attempt' has 769 null value(s).
# Column 'suicide' has 990 null value(s).
# Column 'ideation_of_suicide' has 1829 null value(s).
# Column 'desire_of_death' has 1584 null value(s).
# Column 'Planification_of_suicide' has 1842 null value(s).
# Column 'tm' has 0 null value(s).
# Column 'tm2' has 2116 null value(s).
# Column 'dd_depre' has 63 null value(s).
# Column 'dd_bipolar' has 63 null value(s).
# Column 'dd_sz' has 339 null value(s).
# Column 'dd_psychotic' has 426 null value(s).
# Column 'dd_ADJUST' has 2116 null value(s).
# Column 'dd_anxiety' has 1060 null value(s).
# Column 'dd_cyclothymic' has 854 null value(s).
# Column 'dd_dysthymic' has 623 null value(s).
# Column 'dd_toc' has 1041 null value(s).
# Column 'dd_eating' has 1151 null value(s).
# Column 'dd_al_drug' has 578 null value(s).
# Column 'dd_oh' has 587 null value(s).
# Column 'dd_substance' has 614 null value(s).
# Column 'dd_nbsubstances' has 599 null value(s).
# Column 'dd_cannabis' has 903 null value(s).
# Column 'dd_cocaine' has 904 null value(s).
# Column 'dd_opiate' has 904 null value(s).
# Column 'dd_hallucinogen' has 904 null value(s).
# Column 'dd_inhalant' has 905 null value(s).
# Column 'dd_pcp' has 906 null value(s).
# Column 'dd_sedative' has 905 null value(s).
# Column 'dd_others' has 907 null value(s).
# Column 'dd_SOM' has 2116 null value(s).
# Column 'abortion' has 1605 null value(s).
# Column 'Pregnancy' has 1603 null value(s).
# Column 'CAGE1' has 2044 null value(s).
# Column 'CAGE2' has 2044 null value(s).
# Column 'CAGE3' has 2044 null value(s).
# Column 'CAGE4' has 2044 null value(s).
# Column 'CAGE_TOT' has 2044 null value(s).
# Column 'Score_CAGE' has 2044 null value(s).
# Column 'ctq28_1' has 1435 null value(s).
# Column 'ctq28_2' has 1435 null value(s).
# Column 'ctq28_3' has 1433 null value(s).
# Column 'ctq28_4' has 1437 null value(s).
# Column 'ctq28_5' has 1437 null value(s).
# Column 'ctq28_6' has 1436 null value(s).
# Column 'ctq28_7' has 1439 null value(s).
# Column 'ctq28_8' has 1438 null value(s).
# Column 'ctq28_9' has 1438 null value(s).
# Column 'ctq28_10' has 1469 null value(s).
# Column 'ctq28_11' has 1438 null value(s).
# Column 'ctq28_12' has 1436 null value(s).
# Column 'ctq28_13' has 1440 null value(s).
# Column 'ctq28_14' has 1435 null value(s).
# Column 'ctq28_15' has 1444 null value(s).
# Column 'ctq28_16' has 1440 null value(s).
# Column 'ctq28_17' has 1441 null value(s).
# Column 'ctq28_18' has 1437 null value(s).
# Column 'ctq28_19' has 1436 null value(s).
# Column 'ctq28_20' has 1443 null value(s).
# Column 'ctq28_21' has 1439 null value(s).
# Column 'ctq28_22' has 1436 null value(s).
# Column 'ctq28_23' has 1440 null value(s).
# Column 'ctq28_24' has 1445 null value(s).
# Column 'ctq28_25' has 1445 null value(s).
# Column 'ctq28_26' has 1438 null value(s).
# Column 'ctq28_27' has 1449 null value(s).
# Column 'ctq28_28' has 1437 null value(s).
# Column 'CTQ_emoabus' has 1455 null value(s).
# Column 'CTQ_emotneg' has 1454 null value(s).
# Column 'CTQ_physabus' has 1456 null value(s).
# Column 'CTQ_physnegl' has 1451 null value(s).
# Column 'CTQ_sexabus' has 1461 null value(s).
# Column 'CTQ_total' has 1505 null value(s).
# Column 'mal_1' has 1456 null value(s).
# Column 'mal_2' has 1461 null value(s).
# Column 'mal_3' has 2116 null value(s).
# Column 'mal_4' has 1447 null value(s).
# Column 'mal_5' has 1455 null value(s).
# Column 'mal_6' has 2116 null value(s).
# Column 'mal_7' has 2116 null value(s).
# Column 'BIS1' has 881 null value(s).
# Column 'BIS2' has 887 null value(s).
# Column 'BIS3' has 891 null value(s).
# Column 'BIS4' has 890 null value(s).
# Column 'BIS5' has 890 null value(s).
# Column 'BIS6' has 892 null value(s).
# Column 'BIS7' has 887 null value(s).
# Column 'BIS8' has 885 null value(s).
# Column 'BIS9' has 886 null value(s).
# Column 'BIS10' has 882 null value(s).
# Column 'BIS11' has 890 null value(s).
# Column 'BIS12' has 885 null value(s).
# Column 'BIS13' has 917 null value(s).
# Column 'BIS14' has 890 null value(s).
# Column 'BIS15' has 885 null value(s).
# Column 'BIS16' has 915 null value(s).
# Column 'BIS17' has 886 null value(s).
# Column 'BIS18' has 886 null value(s).
# Column 'BIS19' has 884 null value(s).
# Column 'BIS20' has 883 null value(s).
# Column 'BIS21' has 887 null value(s).
# Column 'BIS22' has 885 null value(s).
# Column 'BIS23' has 879 null value(s).
# Column 'BIS24' has 888 null value(s).
# Column 'BIS25' has 891 null value(s).
# Column 'BIS26' has 885 null value(s).
# Column 'BIS27' has 901 null value(s).
# Column 'BIS28' has 888 null value(s).
# Column 'BIS29' has 884 null value(s).
# Column 'BIS30' has 882 null value(s).
# Column 'BIS31' has 896 null value(s).
# Column 'BIS32' has 890 null value(s).
# Column 'BIS33' has 885 null value(s).
# Column 'BIS34' has 882 null value(s).
# Column 'BIS10_Impulc' has 929 null value(s).
# Column 'BIS10_Impulm' has 928 null value(s).
# Column 'BIS10_impulnp' has 942 null value(s).
# Column 'RRRS1ere1' has 1792 null value(s).
# Column 'RRRS1ere2' has 1789 null value(s).
# Column 'RRRS1ere3' has 1798 null value(s).
# Column 'RRRS1ere4' has 1796 null value(s).
# Column 'RRRS1ere5' has 1799 null value(s).
# Column 'RRRS1ere6' has 1788 null value(s).
# Column 'RRRS1ere7' has 1809 null value(s).
# Column 'RRRS1ere8' has 1807 null value(s).
# Column 'RRRS1ere9' has 1793 null value(s).
# Column 'RRRS1ere10' has 1811 null value(s).
# Column 'RRRS_Risk_1ereTS' has 1811 null value(s).
# Column 'RRRS_Rescue_1ereTS' has 1844 null value(s).
# Column 'RRRS_Ratio_1ereTS' has 1862 null value(s).
# Column 'SIS1ere1' has 1793 null value(s).
# Column 'SIS1ere2' has 1795 null value(s).
# Column 'SIS1ere3' has 1796 null value(s).
# Column 'SIS1ere4' has 1798 null value(s).
# Column 'SIS1ere5' has 1795 null value(s).
# Column 'SIS1ere6' has 1795 null value(s).
# Column 'SIS1ere7' has 1795 null value(s).
# Column 'SIS1ere8' has 1796 null value(s).
# Column 'SIS1ere9' has 1795 null value(s).
# Column 'SIS1ere10' has 1797 null value(s).
# Column 'SIS1ere11' has 1798 null value(s).
# Column 'SIS1ere12' has 1798 null value(s).
# Column 'SIS1ere13' has 1798 null value(s).
# Column 'SIS1ere14' has 1803 null value(s).
# Column 'SIS1ere15' has 1798 null value(s).
# Column 'SIS_1ereplanif' has 1804 null value(s).
# Column 'SIS_1ereconcept' has 1809 null value(s).
# Column 'SIS_1ereTotal' has 1818 null value(s).
# Column 'saa1ere16' has 2009 null value(s).
# Column 'saa1ere17' has 2010 null value(s).
# Column 'saa1ere18' has 2008 null value(s).
# Column 'saa1ere19' has 2049 null value(s).
# Column 'saa1ere20' has 2053 null value(s).
# Column 'sef1ere21' has 2005 null value(s).
# Column 'sef1ere22' has 2003 null value(s).
# Column 'sef1ere23' has 2008 null value(s).
# Column 'sef1ere24' has 2004 null value(s).
# Column 'sef1ere25' has 2004 null value(s).
# Column 'sef1ere26' has 2003 null value(s).
# Column 'SIS1ere27' has 2104 null value(s).
# Column 'SIS1ere28' has 2105 null value(s).
# Column 'SIS1ere28explic' has 2104 null value(s).
# Column 'SIS1ere29' has 2104 null value(s).
# Column 'SIS1ere30' has 2104 null value(s).
# Column 'GRRRS1' has 1415 null value(s).
# Column 'GRRRS2' has 1415 null value(s).
# Column 'GRRRS3' has 1434 null value(s).
# Column 'GRRRS4' has 1432 null value(s).
# Column 'GRRRS5' has 1435 null value(s).
# Column 'GRRRS6' has 1409 null value(s).
# Column 'GRRRS7' has 1442 null value(s).
# Column 'GRRRS8' has 1465 null value(s).
# Column 'GRRRS9' has 1416 null value(s).
# Column 'GRRRS10' has 1443 null value(s).
# Column 'RRRS_GRisk' has 1456 null value(s).
# Column 'RRRS_GRescue' has 1522 null value(s).
# Column 'RRRS_GRatio' has 1560 null value(s).
# Column 'GSIS1' has 1414 null value(s).
# Column 'GSIS2' has 1416 null value(s).
# Column 'GSIS3' has 1420 null value(s).
# Column 'GSIS4' has 1422 null value(s).
# Column 'GSIS5' has 1418 null value(s).
# Column 'GSIS6' has 1416 null value(s).
# Column 'GSIS7' has 1418 null value(s).
# Column 'GSIS8' has 1419 null value(s).
# Column 'GSIS9' has 1417 null value(s).
# Column 'GSIS10' has 1420 null value(s).
# Column 'GSIS11' has 1423 null value(s).
# Column 'GSIS12' has 1421 null value(s).
# Column 'GSIS13' has 1420 null value(s).
# Column 'GSIS14' has 1430 null value(s).
# Column 'GSIS15' has 1422 null value(s).
# Column 'SIS_GPlanif' has 1441 null value(s).
# Column 'SIS_GConcept' has 1441 null value(s).
# Column 'SIS_GTotal' has 1466 null value(s).
# Column 'gSaa16' has 2001 null value(s).
# Column 'gSaa17' has 1998 null value(s).
# Column 'gSaa18' has 1998 null value(s).
# Column 'gSaa19' has 2045 null value(s).
# Column 'gSaa20' has 2053 null value(s).
# Column 'gSef21' has 1951 null value(s).
# Column 'gSef22' has 1948 null value(s).
# Column 'gSef23' has 1953 null value(s).
# Column 'gSef24' has 1954 null value(s).
# Column 'gSef25' has 1948 null value(s).
# Column 'gSef26' has 1947 null value(s).
# Column 'GSIS27' has 2054 null value(s).
# Column 'GSIS28' has 2056 null value(s).
# Column 'GSIS28explic' has 2058 null value(s).
# Column 'GSIS29' has 2053 null value(s).
# Column 'GSIS30' has 2053 null value(s).
# Column 'rrrs_derTS1' has 1517 null value(s).
# Column 'rrrs_derTS2' has 1515 null value(s).
# Column 'rrrs_derTS3' has 1532 null value(s).
# Column 'rrrs_derTS4' has 1529 null value(s).
# Column 'rrrs_derTS5' has 1528 null value(s).
# Column 'rrrs_derTS6' has 1510 null value(s).
# Column 'rrrs_derTS7' has 1543 null value(s).
# Column 'rrrs_derTS8' has 1560 null value(s).
# Column 'rrrs_derTS9' has 1519 null value(s).
# Column 'rrrs_derTS10' has 1543 null value(s).
# Column 'rrrs_derTS_Risk' has 1548 null value(s).
# Column 'rrrs_derTS_Rescue' has 1615 null value(s).
# Column 'rrrs_derTS_Ratio' has 1646 null value(s).
# Column 'SIS_derTS1' has 1617 null value(s).
# Column 'SIS_derTS2' has 1622 null value(s).
# Column 'SIS_derTS3' has 1621 null value(s).
# Column 'SIS_derTS4' has 1624 null value(s).
# Column 'SIS_derTS5' has 1619 null value(s).
# Column 'SIS_derTS6' has 1618 null value(s).
# Column 'SIS_derTS7' has 1620 null value(s).
# Column 'SIS_derTS8' has 1620 null value(s).
# Column 'SIS_derTS9' has 1620 null value(s).
# Column 'SIS_derTS10' has 1622 null value(s).
# Column 'SIS_derTS11' has 1623 null value(s).
# Column 'SIS_derTS12' has 1622 null value(s).
# Column 'SIS_derTS13' has 1622 null value(s).
# Column 'SIS_derTS14' has 1632 null value(s).
# Column 'SIS_derTS15' has 1621 null value(s).
# Column 'Saa_derTS16' has 2006 null value(s).
# Column 'Saa_derTS17' has 2004 null value(s).
# Column 'Saa_derTS18' has 2004 null value(s).
# Column 'Saa_derTS19' has 2048 null value(s).
# Column 'Saa_derTS20' has 2053 null value(s).
# Column 'Sef_derTS21' has 1961 null value(s).
# Column 'Sef_derTS22' has 1959 null value(s).
# Column 'Sef_derTS23' has 1963 null value(s).
# Column 'Sef_derTS24' has 1963 null value(s).
# Column 'Sef_derTS25' has 1960 null value(s).
# Column 'Sef_derTS26' has 1959 null value(s).
# Column 'SIS_derTS27' has 2061 null value(s).
# Column 'SIS_derTS28' has 2061 null value(s).
# Column 'SIS_derTS28explic' has 2067 null value(s).
# Column 'SIS_derTS29' has 2061 null value(s).
# Column 'SIS_derTS30' has 2061 null value(s).
# Column 'SIS_derTS_planif' has 1636 null value(s).
# Column 'SIS_derTS_Concept' has 1636 null value(s).
# Column 'SIS_derTS_Total' has 1653 null value(s).
# Column 'SSI1dts' has 1829 null value(s).
# Column 'SSI2dts' has 1829 null value(s).
# Column 'SSI3dts' has 1830 null value(s).
# Column 'SSI4dts' has 1829 null value(s).
# Column 'SSI5dts' has 1832 null value(s).
# Column 'SSI6dts' has 1842 null value(s).
# Column 'SSI7dts' has 1841 null value(s).
# Column 'SSI8dts' has 1842 null value(s).
# Column 'SSI9dts' has 1841 null value(s).
# Column 'SSI10dts' has 1844 null value(s).
# Column 'SSI11dts' has 1845 null value(s).
# Column 'SSI12dts' has 1842 null value(s).
# Column 'SSI13dts' has 1842 null value(s).
# Column 'SSI14dts' has 1842 null value(s).
# Column 'SSI15dts' has 1844 null value(s).
# Column 'SSI16dts' has 1849 null value(s).
# Column 'SSI17dts' has 1841 null value(s).
# Column 'SSI18dts' has 1841 null value(s).
# Column 'SSI19dts' has 1841 null value(s).
# Column 'SSI20dts' has 1905 null value(s).
# Column 'SSI21dts' has 1929 null value(s).
# Column 'Score_SSIdts' has 1863 null value(s).
# Column 'SSI1_1ereTS' has 1832 null value(s).
# Column 'SSI2_1ereTS' has 1831 null value(s).
# Column 'SSI3_1ereTS' has 1832 null value(s).
# Column 'SSI4_1ereTS' has 1831 null value(s).
# Column 'SSI5_1ereTS' has 1835 null value(s).
# Column 'SSI6_1ereTS' has 1843 null value(s).
# Column 'SSI7_1ereTS' has 1843 null value(s).
# Column 'SSI8_1ereTS' has 1844 null value(s).
# Column 'SSI9_1ereTS' has 1843 null value(s).
# Column 'SSI10_1ereTS' has 1846 null value(s).
# Column 'SSI11_1ereTS' has 1845 null value(s).
# Column 'SSI12_1ereTS' has 1844 null value(s).
# Column 'SSI13_1ereTS' has 1845 null value(s).
# Column 'SSI14_1ereTS' has 1844 null value(s).
# Column 'SSI15_1ereTS' has 1846 null value(s).
# Column 'SSI16_1ereTS' has 1851 null value(s).
# Column 'SSI17_1ereTS' has 1843 null value(s).
# Column 'SSI18_1ereTS' has 1843 null value(s).
# Column 'SSI19_1ereTS' has 1843 null value(s).
# Column 'SSI20_1ereTS' has 1907 null value(s).
# Column 'SSI21_1ereTS' has 1943 null value(s).
# Column 'Score_SSI_1ereTS' has 1864 null value(s).
# Column 'SSI1p' has 1535 null value(s).
# Column 'SSI2p' has 1535 null value(s).
# Column 'SSI3p' has 1536 null value(s).
# Column 'SSI4p' has 1535 null value(s).
# Column 'SSI5p' has 1541 null value(s).
# Column 'SSI6p' has 1553 null value(s).
# Column 'SSI7p' has 1553 null value(s).
# Column 'SSI8p' has 1556 null value(s).
# Column 'SSI9p' has 1553 null value(s).
# Column 'SSI10p' has 1554 null value(s).
# Column 'SSI11p' has 1558 null value(s).
# Column 'SSI12p' has 1556 null value(s).
# Column 'SSI13p' has 1556 null value(s).
# Column 'SSI14p' has 1555 null value(s).
# Column 'SSI15p' has 1559 null value(s).
# Column 'SSI16p' has 1577 null value(s).
# Column 'SSI17p' has 1557 null value(s).
# Column 'SSI18p' has 1555 null value(s).
# Column 'SSI19p' has 1554 null value(s).
# Column 'SSI20p' has 1718 null value(s).
# Column 'SSI21p' has 1757 null value(s).
# Column 'Score_SSIp' has 1599 null value(s).
# Column 'STAXI1' has 994 null value(s).
# Column 'STAXI2' has 997 null value(s).
# Column 'STAXI3' has 998 null value(s).
# Column 'STAXI4' has 998 null value(s).
# Column 'STAXI5' has 1002 null value(s).
# Column 'STAXI6' has 1005 null value(s).
# Column 'STAXI7' has 1002 null value(s).
# Column 'STAXI8' has 1005 null value(s).
# Column 'STAXI9' has 1002 null value(s).
# Column 'STAXI10' has 998 null value(s).
# Column 'STAXI11' has 989 null value(s).
# Column 'STAXI12' has 991 null value(s).
# Column 'STAXI13' has 996 null value(s).
# Column 'STAXI14' has 992 null value(s).
# Column 'STAXI15' has 993 null value(s).
# Column 'STAXI16' has 995 null value(s).
# Column 'STAXI17' has 993 null value(s).
# Column 'STAXI18' has 991 null value(s).
# Column 'STAXI19' has 989 null value(s).
# Column 'STAXI20' has 995 null value(s).
# Column 'STAXI21' has 994 null value(s).
# Column 'STAXI22' has 991 null value(s).
# Column 'STAXI23' has 1001 null value(s).
# Column 'STAXI24' has 1002 null value(s).
# Column 'STAXI25' has 998 null value(s).
# Column 'STAXI26' has 997 null value(s).
# Column 'STAXI27' has 998 null value(s).
# Column 'STAXI28' has 1008 null value(s).
# Column 'STAXI29' has 1004 null value(s).
# Column 'STAXI30' has 1001 null value(s).
# Column 'STAXI31' has 997 null value(s).
# Column 'STAXI32' has 999 null value(s).
# Column 'STAXI33' has 995 null value(s).
# Column 'STAXI34' has 995 null value(s).
# Column 'STAXI35' has 1005 null value(s).
# Column 'STAXI36' has 1003 null value(s).
# Column 'STAXI37' has 1002 null value(s).
# Column 'STAXI38' has 994 null value(s).
# Column 'STAXI39' has 1008 null value(s).
# Column 'STAXI40' has 999 null value(s).
# Column 'STAXI41' has 1007 null value(s).
# Column 'STAXI42' has 1000 null value(s).
# Column 'STAXI43' has 1010 null value(s).
# Column 'STAXI44' has 998 null value(s).
# Column 'STAXI_stateanger' has 1038 null value(s).
# Column 'STAXI_traitanger' has 1010 null value(s).
# Column 'STAXI_Angerin' has 1038 null value(s).
# Column 'STAXI_Angerout' has 1033 null value(s).
# Column 'STAXI_Angecontrol' has 1023 null value(s).
# Column 'BDHI1' has 1196 null value(s).
# Column 'BDHI2' has 1195 null value(s).
# Column 'BDHI3' has 1195 null value(s).
# Column 'BDHI4' has 1198 null value(s).
# Column 'BDHI5' has 1196 null value(s).
# Column 'BDHI6' has 1196 null value(s).
# Column 'BDHI7' has 1202 null value(s).
# Column 'BDHI8' has 1201 null value(s).
# Column 'BDHI9' has 1202 null value(s).
# Column 'BDHI10' has 1200 null value(s).
# Column 'BDHI11' has 1202 null value(s).
# Column 'BDHI12' has 1202 null value(s).
# Column 'BDHI13' has 1206 null value(s).
# Column 'BDHI14' has 1201 null value(s).
# Column 'BDHI15' has 1206 null value(s).
# Column 'BDHI16' has 1200 null value(s).
# Column 'BDHI17' has 1206 null value(s).
# Column 'BDHI18' has 1205 null value(s).
# Column 'BDHI19' has 1205 null value(s).
# Column 'BDHI20' has 1205 null value(s).
# Column 'BDHI21' has 1203 null value(s).
# Column 'BDHI22' has 1207 null value(s).
# Column 'BDHI23' has 1200 null value(s).
# Column 'BDHI24' has 1199 null value(s).
# Column 'BDHI25' has 1206 null value(s).
# Column 'BDHI26' has 1198 null value(s).
# Column 'BDHI27' has 1201 null value(s).
# Column 'BDHI28' has 1202 null value(s).
# Column 'BDHI29' has 1199 null value(s).
# Column 'BDHI30' has 1197 null value(s).
# Column 'BDHI31' has 1201 null value(s).
# Column 'BDHI32' has 1204 null value(s).
# Column 'BDHI33' has 1203 null value(s).
# Column 'BDHI34' has 1198 null value(s).
# Column 'BDHI35' has 1207 null value(s).
# Column 'BDHI36' has 1201 null value(s).
# Column 'BDHI37' has 1205 null value(s).
# Column 'BDHI38' has 1202 null value(s).
# Column 'BDHI39' has 1200 null value(s).
# Column 'BDHI40' has 1205 null value(s).
# Column 'BDHI41' has 1205 null value(s).
# Column 'BDHI42' has 1202 null value(s).
# Column 'BDHI43' has 1202 null value(s).
# Column 'BDHI44' has 1206 null value(s).
# Column 'BDHI45' has 1203 null value(s).
# Column 'BDHI46' has 1203 null value(s).
# Column 'BDHI47' has 1210 null value(s).
# Column 'BDHI48' has 1201 null value(s).
# Column 'BDHI49' has 1203 null value(s).
# Column 'BDHI50' has 1208 null value(s).
# Column 'BDHI51' has 1201 null value(s).
# Column 'BDHI52' has 1207 null value(s).
# Column 'BDHI53' has 1201 null value(s).
# Column 'BDHI54' has 1203 null value(s).
# Column 'BDHI55' has 1207 null value(s).
# Column 'BDHI56' has 1197 null value(s).
# Column 'BDHI57' has 1205 null value(s).
# Column 'BDHI58' has 1201 null value(s).
# Column 'BDHI59' has 1203 null value(s).
# Column 'BDHI60' has 1198 null value(s).
# Column 'BDHI61' has 1202 null value(s).
# Column 'BDHI62' has 1200 null value(s).
# Column 'BDHI63' has 1207 null value(s).
# Column 'BDHI64' has 1201 null value(s).
# Column 'BDHI65' has 1205 null value(s).
# Column 'BDHI66' has 1198 null value(s).
# Column 'BDHI67' has 1204 null value(s).
# Column 'BDHI68' has 1203 null value(s).
# Column 'BDHI69' has 1201 null value(s).
# Column 'BDHI70' has 1200 null value(s).
# Column 'BDHI71' has 1204 null value(s).
# Column 'BDHI72' has 1202 null value(s).
# Column 'BDHI73' has 1204 null value(s).
# Column 'BDHI74' has 1204 null value(s).
# Column 'BDHI75' has 1199 null value(s).
# Column 'BDHI_Impul' has 1236 null value(s).
# Column 'BDHI_Hostind' has 1227 null value(s).
# Column 'BDHI_Irritab' has 1248 null value(s).
# Column 'BDHI_Negativ' has 1217 null value(s).
# Column 'BDHI_Ressent' has 1231 null value(s).
# Column 'BDHI_Suspic' has 1240 null value(s).
# Column 'BDHI_Hostivb' has 1251 null value(s).
# Column 'BDHI_Culpab' has 1231 null value(s).
# Column 'STAIE1' has 1607 null value(s).
# Column 'STAIE2' has 1608 null value(s).
# Column 'STAIE3' has 1612 null value(s).
# Column 'STAIE4' has 1619 null value(s).
# Column 'STAIE5' has 1610 null value(s).
# Column 'STAIE6' has 1609 null value(s).
# Column 'STAIE7' has 1618 null value(s).
# Column 'STAIE8' has 1610 null value(s).
# Column 'STAIE9' has 1608 null value(s).
# Column 'STAIE10' has 1614 null value(s).
# Column 'STAIE11' has 1608 null value(s).
# Column 'STAIE12' has 1610 null value(s).
# Column 'STAIE13' has 1609 null value(s).
# Column 'STAIE14' has 1607 null value(s).
# Column 'STAIE15' has 1612 null value(s).
# Column 'STAIE16' has 1612 null value(s).
# Column 'STAIE17' has 1609 null value(s).
# Column 'STAIE18' has 1609 null value(s).
# Column 'STAIE19' has 1608 null value(s).
# Column 'STAIE20' has 1610 null value(s).
# Column 'STAI_anxiety' has 1683 null value(s).
# Column 'LHA1' has 2116 null value(s).
# Column 'LHA2' has 2116 null value(s).
# Column 'LHA3' has 2116 null value(s).
# Column 'LHA4' has 2116 null value(s).
# Column 'LHA5' has 2116 null value(s).
# Column 'LHA6' has 2116 null value(s).
# Column 'LHA7' has 2116 null value(s).
# Column 'LHA8' has 2116 null value(s).
# Column 'LHA9' has 2116 null value(s).
# Column 'LHA10' has 2116 null value(s).
# Column 'LHA11' has 2116 null value(s).
# Column 'ge_lha1' has 1852 null value(s).
# Column 'ge_lha2' has 1852 null value(s).
# Column 'ge_lha3' has 1852 null value(s).
# Column 'ge_lha4' has 1852 null value(s).
# Column 'ge_lha5' has 1852 null value(s).
# Column 'ge_lha6' has 1852 null value(s).
# Column 'ge_lha7' has 1852 null value(s).
# Column 'ge_lha8' has 2012 null value(s).
# Column 'ge_lha9' has 2012 null value(s).
# Column 'Ge_BrownGood' has 1852 null value(s).
# Column 'weight' has 1717 null value(s).
# Column 'height' has 1713 null value(s).
# Column 'BMI' has 1718 null value(s).
# Column 'DOS12' has 1568 null value(s).
# Column 'Dos23' has 1661 null value(s).
# Column 'DOS24' has 1909 null value(s).
# Column 'DOS25' has 1910 null value(s).
# Column 'DOS26' has 1962 null value(s).
# Column 'DOS27' has 1988 null value(s).
# Column 'DOS28' has 2109 null value(s).
# Column 'DOS29' has 1789 null value(s).
# Column 'Dos30' has 1497 null value(s).
# Column 'DOS31' has 1580 null value(s).
# Column 'DOS32' has 1551 null value(s).
# Column 'DOS33' has 1556 null value(s).
# Column 'DOS34' has 1517 null value(s).
# Column 'DOS35' has 1518 null value(s).
# Column 'DOS36' has 1524 null value(s).
# Column 'DOS37' has 1580 null value(s).
# Column 'DOS38' has 1582 null value(s).
# Column 'DOS39' has 1957 null value(s).
# Column 'DOS40' has 1792 null value(s).
# Column 'DOS41' has 1939 null value(s).
# Column 'DOS42' has 1942 null value(s).
# Column 'DOS43' has 1672 null value(s).
# Column 'DOS44' has 1672 null value(s).
# Column 'DOS45' has 1681 null value(s).
# Column 'DOS46' has 1782 null value(s).
# Column 'DOS47' has 1938 null value(s).
# Column 'DOS48' has 2067 null value(s).
# Column 'Dos49' has 1501 null value(s).
# Column 'DOS50' has 1501 null value(s).
# Column 'DOS51' has 1501 null value(s).
# Column 'DOS52' has 1528 null value(s).
# Column 'DOS53' has 1528 null value(s).
# Column 'DOS54' has 1528 null value(s).
# Column 'DOS55' has 1529 null value(s).
# Column 'DOS56' has 1544 null value(s).
# Column 'DOS57' has 1531 null value(s).
# Column 'DOS58' has 1549 null value(s).
# Column 'DOS59' has 1528 null value(s).
# Column 'Dos60' has 1895 null value(s).
# Column 'DOS61' has 1918 null value(s).
# Column 'DOS62' has 1895 null value(s).
# Column 'DOS63' has 1895 null value(s).
# Column 'DOS64' has 1895 null value(s).
# Column 'DOS65' has 1895 null value(s).
# Column 'Dos66' has 1818 null value(s).
# Column 'DOS67' has 1818 null value(s).
# Column 'DOS_Albumin' has 2116 null value(s).
# Column 'DOS_phosphore' has 2116 null value(s).
# Column 'DOS_VDL' has 2116 null value(s).
# Column 'DOS_apo_e' has 2116 null value(s).
# Column 'DOS_FSH' has 2116 null value(s).
# Column 'DOS_LH' has 2116 null value(s).
# Column 'DOS_E2' has 2116 null value(s).
# Column 'DOS_Progesterone' has 2116 null value(s).
# Column 'DOS_testosterone' has 2116 null value(s).
# Column 'DOS_prolactine' has 2116 null value(s).
# Column 'BDNF_valmet' has 10 null value(s).
# Column 'COMT' has 3 null value(s).
# Column 'HT1A' has 5 null value(s).
# Column 'HT1B_161' has 1 null value(s).
# Column 'HT1B_861' has 4 null value(s).
# Column 'VHT2A_1438' has 2017 null value(s).
# Column 'VHT2A_C102T' has 1049 null value(s).
# Column 'VHTTP_mutation_seule' has 190 null value(s).
# Column 'VHTTP_LPR' has 190 null value(s).
# Column '@_httpb_promoteur' has 9 null value(s).
# Column 'VHTTP_snippassocie' has 190 null value(s).
# Column 'VHTTP_Intron2' has 910 null value(s).
# Column 'TPH1_intron1b' has 1107 null value(s).
# Column 'TPH1_promo' has 0 null value(s).
# Column 'TPH1_Intron3' has 932 null value(s).
# Column 'TPH1_Intron4' has 1 null value(s).
# Column 'TPH1_Intron7' has 1 null value(s).
# Column 'TPH1_Intron9' has 1637 null value(s).
# Column 'TPH1_T8687' has 1734 null value(s).
# Column 'TPH2_8997' has 596 null value(s).
# Column 'TPH2_9000_Eco72_1' has 22 null value(s).
# Column 'TPH2_9000_Aci_I' has 21 null value(s).
# Column 'TPH2_Intron5' has 708 null value(s).
# Column 'TPH2_Exon7' has 5 null value(s).
# Column 'TPH2_Intron9' has 681 null value(s).
# Column 'MAOA_Promo' has 9 null value(s).
# Column 'MAOA_promo_activite' has 20 null value(s).

# %%
null_counts = df.isnull().sum()
columns_to_drop = null_counts[null_counts > 600].index
df = df.drop(columns=columns_to_drop)

print("DataFrame after dropping columns:")
print(df.columns)
# Out:
# DataFrame after dropping columns:
# Index(['IDENTIFICADOR', 'source', 'type', 'assessment_date', 'gender', 'age',
#        'ethnicity', 'Suicidal_behavior', 'num_suic_attempts', 'tm', 'dd_depre',
#        'dd_bipolar', 'dd_sz', 'dd_psychotic', 'dd_al_drug', 'dd_oh',
#        'dd_nbsubstances', 'BDNF_valmet', 'COMT', 'HT1A', 'HT1B_161',
#        'HT1B_861', 'VHTTP_mutation_seule', 'VHTTP_LPR', '@_httpb_promoteur',
#        'VHTTP_snippassocie', 'TPH1_promo', 'TPH1_Intron4', 'TPH1_Intron7',
#        'TPH2_8997', 'TPH2_9000_Eco72_1', 'TPH2_9000_Aci_I', 'TPH2_Exon7',
#        'MAOA_Promo', 'MAOA_promo_activite'],
#       dtype='object')

# %%
for column in df.columns:
    null_count = df[column].isnull().sum()
    print(f"Column '{column}' has {null_count} null value(s).")
# Out:
# Column 'IDENTIFICADOR' has 0 null value(s).
# Column 'source' has 0 null value(s).
# Column 'type' has 0 null value(s).
# Column 'assessment_date' has 509 null value(s).
# Column 'gender' has 0 null value(s).
# Column 'age' has 4 null value(s).
# Column 'ethnicity' has 5 null value(s).
# Column 'Suicidal_behavior' has 285 null value(s).
# Column 'num_suic_attempts' has 321 null value(s).
# Column 'tm' has 0 null value(s).
# Column 'dd_depre' has 63 null value(s).
# Column 'dd_bipolar' has 63 null value(s).
# Column 'dd_sz' has 339 null value(s).
# Column 'dd_psychotic' has 426 null value(s).
# Column 'dd_al_drug' has 578 null value(s).
# Column 'dd_oh' has 587 null value(s).
# Column 'dd_nbsubstances' has 599 null value(s).
# Column 'BDNF_valmet' has 10 null value(s).
# Column 'COMT' has 3 null value(s).
# Column 'HT1A' has 5 null value(s).
# Column 'HT1B_161' has 1 null value(s).
# Column 'HT1B_861' has 4 null value(s).
# Column 'VHTTP_mutation_seule' has 190 null value(s).
# Column 'VHTTP_LPR' has 190 null value(s).
# Column '@_httpb_promoteur' has 9 null value(s).
# Column 'VHTTP_snippassocie' has 190 null value(s).
# Column 'TPH1_promo' has 0 null value(s).
# Column 'TPH1_Intron4' has 1 null value(s).
# Column 'TPH1_Intron7' has 1 null value(s).
# Column 'TPH2_8997' has 596 null value(s).
# Column 'TPH2_9000_Eco72_1' has 22 null value(s).
# Column 'TPH2_9000_Aci_I' has 21 null value(s).
# Column 'TPH2_Exon7' has 5 null value(s).
# Column 'MAOA_Promo' has 9 null value(s).
# Column 'MAOA_promo_activite' has 20 null value(s).

# %%
k = 0
for column in df.columns:
    k = k +1
    print("Column",k , column)
# Out:
# Column 1 IDENTIFICADOR
# Column 2 source
# Column 3 type
# Column 4 assessment_date
# Column 5 gender
# Column 6 age
# Column 7 ethnicity
# Column 8 Suicidal_behavior
# Column 9 num_suic_attempts
# Column 10 tm
# Column 11 dd_depre
# Column 12 dd_bipolar
# Column 13 dd_sz
# Column 14 dd_psychotic
# Column 15 dd_al_drug
# Column 16 dd_oh
# Column 17 dd_nbsubstances
# Column 18 BDNF_valmet
# Column 19 COMT
# Column 20 HT1A
# Column 21 HT1B_161
# Column 22 HT1B_861
# Column 23 VHTTP_mutation_seule
# Column 24 VHTTP_LPR
# Column 25 @_httpb_promoteur
# Column 26 VHTTP_snippassocie
# Column 27 TPH1_promo
# Column 28 TPH1_Intron4
# Column 29 TPH1_Intron7
# Column 30 TPH2_8997
# Column 31 TPH2_9000_Eco72_1
# Column 32 TPH2_9000_Aci_I
# Column 33 TPH2_Exon7
# Column 34 MAOA_Promo
# Column 35 MAOA_promo_activite

# %%
# indices_to_drop = [45:72, 79:116, 120:146, 150:193, 199:274]
# df.drop(df.columns[indices_to_drop], axis=1, inplace=True)

# print(df)

# indices_to_drop = list(range(45, 73)) + list(range(79, 117)) + list(range(120, 147)) + list(range(150, 194)) + list(range(199, 275))
# df.drop(df.columns[indices_to_drop], axis=1, inplace=True)

# print(df.columns)

#NOW DROP SOME OF THE COLUMNS

names_list = ['IDENTIFICADOR', 'gender', 'ethnicity', 'age', 'source', 'num_suic_attempts', 'tm', 'dd_depre', 'dd_bipolar', 'dd_sz', 'dd_psychotic', 'dd_al_drug', 'dd_oh', 'dd_nbsubstances', 'assessment_date']

df.drop(names_list, axis=1, inplace=True)

# %%
#df.head()
k = 0
for column in df.columns:

    print("Column",k , column)
    k = k +1
# Out:
# Column 0 type
# Column 1 Suicidal_behavior
# Column 2 BDNF_valmet
# Column 3 COMT
# Column 4 HT1A
# Column 5 HT1B_161
# Column 6 HT1B_861
# Column 7 VHTTP_mutation_seule
# Column 8 VHTTP_LPR
# Column 9 @_httpb_promoteur
# Column 10 VHTTP_snippassocie
# Column 11 TPH1_promo
# Column 12 TPH1_Intron4
# Column 13 TPH1_Intron7
# Column 14 TPH2_8997
# Column 15 TPH2_9000_Eco72_1
# Column 16 TPH2_9000_Aci_I
# Column 17 TPH2_Exon7
# Column 18 MAOA_Promo
# Column 19 MAOA_promo_activite

# %%
# Define mapping
mapping = {12: 1, 7: 1, 4: 0, 5: 0, 6: 0}

# Encode 'type' column, providing a default value of -1 for unspecified values
df['type'] = df['type'].map(mapping).fillna(-1).astype(int)

print(df['type'])


df = df[df['type'] != -1]
# Out:
# 23      1
# 24      1
# 29      1
# 31      1
# 34      1
#        ..
# 8688    1
# 8689    1
# 8691    0
# 8692    1
# 8693    1
# Name: type, Length: 2116, dtype: int64

# %%
print(df['type'].unique())
# Out:
# [1 0]

# %%
# !pip install fancyimpute
# Out:
# Requirement already satisfied: fancyimpute in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (0.7.0)
# Requirement already satisfied: knnimpute>=0.1.0 in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from fancyimpute) (0.1.0)
# Requirement already satisfied: scikit-learn>=0.24.2 in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from fancyimpute) (1.3.2)
# Requirement already satisfied: cvxpy in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from fancyimpute) (1.4.1)
# Requirement already satisfied: cvxopt in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from fancyimpute) (1.3.2)
# Requirement already satisfied: pytest in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from fancyimpute) (7.4.0)
# Requirement already satisfied: nose in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from fancyimpute) (1.3.7)
# Requirement already satisfied: six in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from knnimpute>=0.1.0->fancyimpute) (1.16.0)
# Requirement already satisfied: numpy>=1.10 in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from knnimpute>=0.1.0->fancyimpute) (1.22.4)
# Requirement already satisfied: scipy>=1.5.0 in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.24.2->fancyimpute) (1.7.3)
# Requirement already satisfied: joblib>=1.1.1 in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.24.2->fancyimpute) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.24.2->fancyimpute) (2.2.0)
# Requirement already satisfied: osqp>=0.6.2 in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from cvxpy->fancyimpute) (0.6.3)
# Requirement already satisfied: ecos>=2 in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from cvxpy->fancyimpute) (2.0.12)
# Requirement already satisfied: clarabel>=0.5.0 in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from cvxpy->fancyimpute) (0.6.0)
# Requirement already satisfied: scs>=3.0 in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from cvxpy->fancyimpute) (3.2.4.post1)
# Requirement already satisfied: pybind11 in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from cvxpy->fancyimpute) (2.11.1)
# Requirement already satisfied: iniconfig in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from pytest->fancyimpute) (1.1.1)
# Requirement already satisfied: packaging in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from pytest->fancyimpute) (23.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from pytest->fancyimpute) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from pytest->fancyimpute) (1.0.4)
# Requirement already satisfied: tomli>=1.0.0 in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from pytest->fancyimpute) (2.0.1)
# Requirement already satisfied: qdldl in /Users/filipponardi/opt/anaconda3/lib/python3.9/site-packages (from osqp>=0.6.2->cvxpy->fancyimpute) (0.1.7.post0)
#
# [notice] A new release of pip is available: 22.3.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
from fancyimpute import KNN
from sklearn.preprocessing import LabelEncoder
# adding to be imputed global category along with features
features = ['BDNF_valmet', 'COMT', 'HT1A', 'HT1B_161', 'HT1B_861', 'VHTTP_mutation_seule', 'VHTTP_LPR', '@_httpb_promoteur', 'VHTTP_snippassocie', 'TPH1_promo', 'TPH1_Intron4', 'TPH1_Intron7', 'TPH2_8997', 'TPH2_9000_Eco72_1', 'TPH2_9000_Aci_I', 'TPH2_Exon7', 'MAOA_Promo', 'MAOA_promo_activite']


dfk = df.copy()

#print(dfk['TPH1_promo'], "PRIMA ")

na_index_dict = {}
#to find indexes
for feature in features:
    na_index = dfk[feature].index[dfk[feature].isnull()].tolist()
    if na_index:
        na_index_dict[feature] = na_index[0]


encoder_dict = {}
le = LabelEncoder()
# Encode selected columns
for column in features:
    le = LabelEncoder()
    dfk[column] = le.fit_transform(dfk[column])
    encoder_dict[column] = le  # Store the encoder for later use

#print(dfk['TPH1_promo'], "ENCODED ")

#to replace encoded to na
for feature in features:
    na_index = na_index_dict.get(feature)
    if na_index is not None:
        val = dfk.loc[na_index, feature]
        dfk[feature] = dfk[feature].replace(val, np.nan)

#print(dfk['TPH1_promo'], "REPLACED ")

knn_imputer = KNN()

dfj = knn_imputer.fit_transform(dfk)
dfi = pd.DataFrame(dfj, columns=dfk.columns)
# decoding features

# Assuming 'df' is your DataFrame and 'features' is a list of columns to be inverse label encoded
for column in features:
    le = encoder_dict[column]  # Retrieve the appropriate encoder for the column
    dfi[column] = dfi[column].astype(int)  # Convert the column to integer type
    dfi[column] = le.inverse_transform(dfi[column])


print(dfi['TPH1_promo'])
# Out:
# Imputing row 1/1712 with 0 missing, elapsed time: 0.350
# Imputing row 101/1712 with 1 missing, elapsed time: 0.352
# Imputing row 201/1712 with 0 missing, elapsed time: 0.353
# Imputing row 301/1712 with 0 missing, elapsed time: 0.355
# Imputing row 401/1712 with 1 missing, elapsed time: 0.356
# Imputing row 501/1712 with 0 missing, elapsed time: 0.357
# Imputing row 601/1712 with 0 missing, elapsed time: 0.358
# Imputing row 701/1712 with 0 missing, elapsed time: 0.359
# Imputing row 801/1712 with 0 missing, elapsed time: 0.361
# Imputing row 901/1712 with 0 missing, elapsed time: 0.362
# Imputing row 1001/1712 with 0 missing, elapsed time: 0.363
# Imputing row 1101/1712 with 0 missing, elapsed time: 0.364
# Imputing row 1201/1712 with 0 missing, elapsed time: 0.366
# Imputing row 1301/1712 with 4 missing, elapsed time: 0.367
# Imputing row 1401/1712 with 0 missing, elapsed time: 0.367
# Imputing row 1501/1712 with 0 missing, elapsed time: 0.370
# Imputing row 1601/1712 with 0 missing, elapsed time: 0.372
# Imputing row 1701/1712 with 0 missing, elapsed time: 0.374
# 0       12
# 1       11
# 2       12
# 3       12
# 4       12
#         ..
# 1707    11
# 1708    12
# 1709    12
# 1710    12
# 1711    11
# Name: TPH1_promo, Length: 1712, dtype: object

# %%
subset = dfi.copy()
encoder_dict = {}
le = LabelEncoder()
# Encode selected columns
for column in features:
    le = LabelEncoder()
    subset[column] = le.fit_transform(dfi[column])
    encoder_dict[column] = le  # Store the encoder for later use


subset = pd.DataFrame(subset, columns=subset.columns)

# %%
subset.drop("Suicidal_behavior", axis=1, inplace=True)

# %%
X = subset.drop('type', axis=1)
Y = subset['type'].values
#X = data.drop('Y', axis=1)
y = subset['type']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.25, random_state=42)

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.inspection import permutation_importance

# Assuming X_train and y_train are your training data
rf = RandomForestClassifier()
rf.fit(X_train, y_train)

# Calculate permutation importances
perm_importance = permutation_importance(rf, X_train, y_train, n_repeats=30, random_state=42)

# Get mean importance and feature names
mean_importance = perm_importance['importances_mean']
feature_names = X_train.columns  # Assuming X_train is a pandas DataFrame

# Create a dictionary to map feature names to their importance
importance_dict = {feature_name: importance for feature_name, importance in zip(feature_names, mean_importance)}

# Sort features by importance
sorted_importance = sorted(importance_dict.items(), key=lambda x: x[1], reverse=True)

# Print or access feature importances sorted by importance
for feature, importance in sorted_importance:
    print(f"Feature: {feature}, Mean Importance: {importance}")
# Out:
# Feature: MAOA_promo_activite, Mean Importance: 0.08346313603322944
# Feature: MAOA_Promo, Mean Importance: 0.07468847352024918
# Feature: TPH1_promo, Mean Importance: 0.0684579439252336
# Feature: TPH2_Exon7, Mean Importance: 0.0651609553478712
# Feature: COMT, Mean Importance: 0.06246105919003112
# Feature: BDNF_valmet, Mean Importance: 0.05924195223260641
# Feature: HT1A, Mean Importance: 0.05623052959501553
# Feature: HT1B_161, Mean Importance: 0.05155763239875387
# Feature: HT1B_861, Mean Importance: 0.046547248182762166
# Feature: TPH1_Intron7, Mean Importance: 0.046443406022845246
# Feature: TPH1_Intron4, Mean Importance: 0.041770508826583556
# Feature: VHTTP_snippassocie, Mean Importance: 0.038369678089304235
# Feature: TPH2_9000_Eco72_1, Mean Importance: 0.0367082035306334
# Feature: @_httpb_promoteur, Mean Importance: 0.027336448598130805
# Feature: VHTTP_LPR, Mean Importance: 0.018302180685358212
# Feature: TPH2_9000_Aci_I, Mean Importance: 0.013317757009345762
# Feature: TPH2_8997, Mean Importance: 0.005893042575285519
# Feature: VHTTP_mutation_seule, Mean Importance: 0.005815160955347831

# %%
import matplotlib.pyplot as plt

# Extract sorted feature names and importances
sorted_feature_names = [feature[0] for feature in sorted_importance]
sorted_importances = [feature[1] for feature in sorted_importance]

# Plotting the feature importances
plt.figure(figsize=(10, 6))
plt.barh(sorted_feature_names, sorted_importances, color='skyblue')
plt.xlabel('Mean Importance')
plt.title('Feature Importances')
plt.gca().invert_yaxis()  # Invert y-axis to display features with the most important at the top
plt.tight_layout()
plt.show()

# %%
subset = dfi.copy()
encoder_dict = {}
le = LabelEncoder()
# Encode selected columns
for column in features:
    le = LabelEncoder()
    subset[column] = le.fit_transform(dfi[column])
    encoder_dict[column] = le  # Store the encoder for later use


subset = pd.DataFrame(subset, columns=subset.columns)

# %%
subset.drop("type", axis=1, inplace=True)

# %%
X = subset.drop('Suicidal_behavior', axis=1)
Y = subset['Suicidal_behavior'].values
#X = data.drop('Y', axis=1)
y = subset['Suicidal_behavior']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.25, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.inspection import permutation_importance

# Assuming X_train and y_train are your training data
rf = RandomForestRegressor()
rf.fit(X_train, y_train)

# Calculate permutation importances
perm_importance = permutation_importance(rf, X_train, y_train, n_repeats=30, random_state=42)

# Get mean importance and feature names
mean_importance = perm_importance['importances_mean']
feature_names = X_train.columns  # Assuming X_train is a pandas DataFrame

# Create a dictionary to map feature names to their importance
importance_dict = {feature_name: importance for feature_name, importance in zip(feature_names, mean_importance)}

# Sort features by importance
sorted_importance = sorted(importance_dict.items(), key=lambda x: x[1], reverse=True)

# Print or access feature importances sorted by importance
for feature, importance in sorted_importance:
    print(f"Feature: {feature}, Mean Importance: {importance}")
# Out:
# Feature: MAOA_promo_activite, Mean Importance: 0.313752918706826
# Feature: TPH2_Exon7, Mean Importance: 0.2820477658358088
# Feature: TPH1_promo, Mean Importance: 0.2399679161317639
# Feature: COMT, Mean Importance: 0.227374894479409
# Feature: MAOA_Promo, Mean Importance: 0.2268431030017149
# Feature: VHTTP_snippassocie, Mean Importance: 0.19580173162128087
# Feature: HT1A, Mean Importance: 0.19031147866174505
# Feature: BDNF_valmet, Mean Importance: 0.18579320008921096
# Feature: HT1B_161, Mean Importance: 0.1777821801160447
# Feature: @_httpb_promoteur, Mean Importance: 0.169798188413604
# Feature: HT1B_861, Mean Importance: 0.1651332035676784
# Feature: TPH1_Intron7, Mean Importance: 0.1598645566509663
# Feature: TPH1_Intron4, Mean Importance: 0.14169955037374551
# Feature: TPH2_9000_Eco72_1, Mean Importance: 0.14155799182736176
# Feature: VHTTP_LPR, Mean Importance: 0.10090515239212117
# Feature: TPH2_9000_Aci_I, Mean Importance: 0.045231253682355206
# Feature: TPH2_8997, Mean Importance: 0.02133597278652669
# Feature: VHTTP_mutation_seule, Mean Importance: 0.018663804762953873

# %%
import matplotlib.pyplot as plt

# Extract sorted feature names and importances
sorted_feature_names = [feature[0] for feature in sorted_importance]
sorted_importances = [feature[1] for feature in sorted_importance]

# Plotting the feature importances
plt.figure(figsize=(10, 6))
plt.barh(sorted_feature_names, sorted_importances, color='skyblue')
plt.xlabel('Mean Importance')
plt.title('Feature Importances')
plt.gca().invert_yaxis()  # Invert y-axis to display features with the most important at the top
plt.tight_layout()
plt.show()

# %%
import shap

def shapvals(X_train, X_test, y_train, y_test, model, test_size=0.2, random_state=42):
    model.fit(X_train, y_train)
    # Initialize the SHAP explainer
    explainer = shap.Explainer(model, X_train)
    # Calculate Shapley values for all features
    shapley_values = explainer.shap_values(X_test)
    mean_shapley_values = np.mean(np.abs(shapley_values), axis=0)
    shapley_dict = {feature: shapley_value for feature, shapley_value in zip(X_test.columns, mean_shapley_values)}
    # Sort the dictionary by Shapley values in descending order
    shapley_dict = dict(sorted(shapley_dict.items(), key=lambda item: item[1], reverse=True))

    return shapley_dict

# %%
foshap = shapvals(X_train, X_test, y_train, y_test, rf)

# %%
print('Feature importance with scaled explained using Shap values under random forest')
for idx, n in enumerate(foshap.items()):
  print(f"{idx + 1}. {n[0]}: {n[1]}")
# Out:
# Feature importance with scaled explained using Shap values under random forest
# 1. MAOA_promo_activite: 0.043882232190880936
# 2. TPH1_promo: 0.03104562844613175
# 3. TPH2_Exon7: 0.027609088967405482
# 4. VHTTP_snippassocie: 0.026586184522838504
# 5. BDNF_valmet: 0.022603188163690457
# 6. MAOA_Promo: 0.021002632716489174
# 7. COMT: 0.019021979479783895
# 8. HT1B_161: 0.01797437102121885
# 9. HT1A: 0.015013753756454673
# 10. @_httpb_promoteur: 0.014811654987150707
# 11. TPH1_Intron4: 0.0147220867585103
# 12. VHTTP_LPR: 0.014444985660590066
# 13. TPH1_Intron7: 0.014369032653579758
# 14. TPH2_9000_Eco72_1: 0.013144196780073664
# 15. HT1B_861: 0.011469119965677108
# 16. VHTTP_mutation_seule: 0.00404509803475961
# 17. TPH2_9000_Aci_I: 0.003917876265185065
# 18. TPH2_8997: 0.0018978468179457859
